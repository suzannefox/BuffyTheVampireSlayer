# %%
# %load_ext autoreload
# %autoreload 2

# %%
import buffy_functions as bf

df = bf.get_buffydata_from_wikipedia("Episode Information.txt")
series_info = bf.buffy_series_metadata(df)
fig = bf.plot_buffy_viewers(df, series_info)

fig.show()

# %%
import buffy_functions as bf
fig_filtered = bf.filter_plot(fig, df, 'Writer', 'Fox')
fig_filtered.show()
